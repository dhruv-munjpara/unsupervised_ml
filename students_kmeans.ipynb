# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
df=pd.read_csv("students_kmeans.csv")
df
# Out:
#     Student_ID  Study_Hours_Per_Day  Exam_Score
# 0            1                  2.0          45
# 1            2                  3.0          50
# 2            3                  1.0          40
# 3            4                  2.5          48
# 4            5                  3.0          52
# 5            6                  8.0          88
# 6            7                  9.0          92
# 7            8                  7.5          85
# 8            9                  8.5          90
# 9           10                  9.0          95
# 10          11                  5.0          65
# 11          12                  4.5          60
# 12          13                  5.5          68
# 13          14                  4.0          58
# 14          15                  5.0          63
# 15          16                  1.5          42
# 16          17                  2.0          47
# 17          18                  8.0          87
# 18          19                  6.0          70
# 19          20                  5.5          66

# %%
x=df[["Study_Hours_Per_Day","Exam_Score"]]
print(x.head())
# Out:
#    Study_Hours_Per_Day  Exam_Score
# 0                  2.0          45
# 1                  3.0          50
# 2                  1.0          40
# 3                  2.5          48
# 4                  3.0          52

# %%
kmeans=KMeans(n_clusters=3,random_state=42)
kmeans.fit(x)
# Out:
# KMeans(n_clusters=3, random_state=42)

# %%
df["cluster"]=kmeans.predict(x)
print(df)
# Out:
#     Student_ID  Study_Hours_Per_Day  Exam_Score  cluster
# 0            1                  2.0          45        2
# 1            2                  3.0          50        2
# 2            3                  1.0          40        2
# 3            4                  2.5          48        2
# 4            5                  3.0          52        2
# 5            6                  8.0          88        0
# 6            7                  9.0          92        0
# 7            8                  7.5          85        0
# 8            9                  8.5          90        0
# 9           10                  9.0          95        0
# 10          11                  5.0          65        1
# 11          12                  4.5          60        1
# 12          13                  5.5          68        1
# 13          14                  4.0          58        1
# 14          15                  5.0          63        1
# 15          16                  1.5          42        2
# 16          17                  2.0          47        2
# 17          18                  8.0          87        0
# 18          19                  6.0          70        1
# 19          20                  5.5          66        1

# %%
plt.scatter(df["Study_Hours_Per_Day"],df["Exam_Score"],c=df["cluster"])

plt.xlabel("Study_Hours_Per_Day")
plt.ylabel("Exam_Score")
plt.title("student clustering")

plt.show()
