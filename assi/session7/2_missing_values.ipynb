# %% [markdown]
# # Question 2

# %%
import pandas as pd

df = pd.read_csv("Mall_Customers.csv")

print("Age:", df["Age"].isnull().sum())
print("Annual Income (k$):", df["Annual Income (k$)"].isnull().sum())
print("Spending Score (1-100):", df["Spending Score (1-100)"].isnull().sum())
# Out:
# Age: 0
# Annual Income (k$): 0
# Spending Score (1-100): 0
