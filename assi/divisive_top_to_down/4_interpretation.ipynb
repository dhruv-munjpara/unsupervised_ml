# %% [markdown]
# # 4_interpretation

# %%
print("Dendrogram Interpretation")
print("1. Clusters joined at lower heights are more similar.")
print("2. Clusters joined at higher heights are more different.")
print("3. Long vertical branches indicate well-separated clusters.")
print("4. Cutting the dendrogram at a chosen height determines the number of clusters.")
# Out:
# Dendrogram Interpretation
# 1. Clusters joined at lower heights are more similar.
# 2. Clusters joined at higher heights are more different.
# 3. Long vertical branches indicate well-separated clusters.
# 4. Cutting the dendrogram at a chosen height determines the number of clusters.
