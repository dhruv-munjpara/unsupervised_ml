# %% [markdown]
# # 2_hierarchical_clustering

# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import linkage,dendrogram

songs=pd.DataFrame({
"Song":["S1","S2","S3","S4","S5","S6","S7","S8"],
"Tempo":[120,130,118,140,125,150,135,128],
"Energy":[0.80,0.90,0.75,0.95,0.82,0.98,0.88,0.84]
})

Z=linkage(songs[["Tempo","Energy"]],method="single")
dendrogram(Z,labels=songs["Song"].values)
plt.show()
