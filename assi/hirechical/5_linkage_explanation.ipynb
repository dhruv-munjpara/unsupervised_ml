# %% [markdown]
# # 5_linkage_explanation

# %%
print("Recommended Linkage Method: Ward")
print("Reason:")
print("1. Minimizes within-cluster variance.")
print("2. Produces compact clusters.")
print("3. Good for movie recommendations.")
print("4. Less sensitive to noise than single linkage.")
# Out:
# Recommended Linkage Method: Ward
# Reason:
# 1. Minimizes within-cluster variance.
# 2. Produces compact clusters.
# 3. Good for movie recommendations.
# 4. Less sensitive to noise than single linkage.
