# %%
import pandas as pd 
import matplotlib.pyplot as plt 
from scipy.cluster.hierarchy import linkage, dendrogram

data = {
    'x' : [1,2,3,4,5,3,4,6,7,9,3,4,9,4],
    'y' : [1,2,4,3,5,4,6,5,7,3,2,5,7,6]
}

df = pd.DataFrame(data)

print(df)

linked = linkage(df,method="ward")

plt.figure(figsize=(8,5))
dendrogram(linked)

plt.title("Dendogram")
plt.xlabel("Data Points")
plt.ylabel("Distance")
plt.show()
# Out:
#     x  y
# 0   1  1
# 1   2  2
# 2   3  4
# 3   4  3
# 4   5  5
# 5   3  4
# 6   4  6
# 7   6  5
# 8   7  7
# 9   9  3
# 10  3  2
# 11  4  5
# 12  9  7
# 13  4  6
